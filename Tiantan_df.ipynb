# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Gucheng_df = pd.read_csv("https://raw.githubusercontent.com/ortenox/data_analyst_project/main/PRSA_Data_Aotizhongxin_20130301-20170228.csv")

# %%
Gucheng_df.head(30)
# Out:
#     No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0    1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1    2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2    3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3    4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4    5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
# 5    6  2013      3    1     5    5.0   5.0  18.0  18.0  400.0  66.0  -2.2
# 6    7  2013      3    1     6    3.0   3.0  18.0  32.0  500.0  50.0  -2.6
# 7    8  2013      3    1     7    3.0   6.0  19.0  41.0  500.0  43.0  -1.6
# 8    9  2013      3    1     8    3.0   6.0  16.0  43.0  500.0  45.0   0.1
# 9   10  2013      3    1     9    3.0   8.0  12.0  28.0  400.0  59.0   1.2
# 10  11  2013      3    1    10    3.0   6.0   9.0  12.0  400.0  72.0   1.9
# ...

# %%
Gucheng_df.info()
print("Jumlah missing values: \n", Gucheng_df.isna().sum())
print("Jumlah duplikasi: ", Gucheng_df.duplicated().sum())
Gucheng_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# Jumlah missing values:
# ...

# %%
Gucheng_df[(Gucheng_df['PM2.5'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5   PM10      SO2      NO2      CO  \
# 1509    1510  2013      5    2    21    NaN  183.0  63.0000  93.0000  1200.0
# 1837    1838  2013      5   16    13    NaN   98.0  46.0000  35.0000   600.0
# 2368    2369  2013      6    7    16    NaN  137.0  12.0000  74.0000  2500.0
# 2785    2786  2013      6   25     1    NaN   35.0   3.1416  35.1063     NaN
# 2808    2809  2013      6   26     0    NaN  183.0  64.2600  40.0335     NaN
# ...      ...   ...    ...  ...   ...    ...    ...      ...      ...     ...
# 34880  34881  2017      2   21     8    NaN    NaN      NaN      NaN     NaN
# 34883  34884  2017      2   21    11    NaN    NaN      NaN      NaN     NaN
# 34885  34886  2017      2   21    13    NaN    NaN      NaN      NaN     NaN
# 35028  35029  2017      2   27    12    NaN    NaN      NaN      NaN     NaN
# 35029  35030  2017      2   27    13    NaN    NaN      NaN      NaN     NaN
#
# ...

# %%
Gucheng_df['PM2.5'].fillna(value=Gucheng_df['PM2.5'].mean(), inplace=True)

# %%
Gucheng_df[(Gucheng_df['PM2.5'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Gucheng_df[(Gucheng_df['PM10'].isna())]
# Out:
#           No  year  month  day  hour      PM2.5  PM10   SO2   NO2      CO  \
# 204      205  2013      3    9    12  78.000000   NaN  10.0  10.0   300.0
# 2949    2950  2013      7    1    21  85.000000   NaN  12.0  79.0  2100.0
# 3133    3134  2013      7    9    13  52.000000   NaN   6.0  50.0   700.0
# 4513    4514  2013      9    5     1  24.000000   NaN   1.0  35.0   400.0
# 4706    4707  2013      9   13     2  61.000000   NaN   2.0  35.0   500.0
# ...      ...   ...    ...  ...   ...        ...   ...   ...   ...     ...
# 34880  34881  2017      2   21     8  82.773611   NaN   NaN   NaN     NaN
# 34883  34884  2017      2   21    11  82.773611   NaN   NaN   NaN     NaN
# 34885  34886  2017      2   21    13  82.773611   NaN   NaN   NaN     NaN
# 35028  35029  2017      2   27    12  82.773611   NaN   NaN   NaN     NaN
# 35029  35030  2017      2   27    13  82.773611   NaN   NaN   NaN     NaN
#
#          O3  TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
Gucheng_df['PM10'].fillna(value=Gucheng_df['PM10'].mean(), inplace=True)

# %%
Gucheng_df[(Gucheng_df['PM10'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Gucheng_df[(Gucheng_df['SO2'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10  SO2    NO2  \
# 74        75  2013      3    4     2   34.000000   62.000000  NaN   14.0
# 170      171  2013      3    8     2  339.000000  400.000000  NaN  162.0
# 627      628  2013      3   27     3  129.000000  163.000000  NaN   54.0
# 628      629  2013      3   27     4  135.000000  161.000000  NaN   54.0
# 629      630  2013      3   27     5  135.000000  153.000000  NaN   64.0
# ...      ...   ...    ...  ...   ...         ...         ...  ...    ...
# 34885  34886  2017      2   21    13   82.773611  110.060391  NaN    NaN
# 34912  34913  2017      2   22    16  131.000000  131.000000  NaN   95.0
# 35027  35028  2017      2   27    11  122.000000  122.000000  NaN    NaN
# 35028  35029  2017      2   27    12   82.773611  110.060391  NaN    NaN
# 35029  35030  2017      2   27    13   82.773611  110.060391  NaN    NaN
#
#            CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
Gucheng_df.SO2.value_counts()
# Out:
# SO2
# 2.0000      6706
# 3.0000      2275
# 4.0000      1901
# 5.0000      1680
# 6.0000      1493
#             ...
# 17.1360        1
# 18.2784        1
# 24.2760        1
# 25.4184        1
# 157.0000       1
# Name: count, Length: 330, dtype: int64

# %%
Gucheng_df.SO2.fillna(value=2.0000, inplace=True)

# %%
Gucheng_df[(Gucheng_df['SO2'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
print("Jumlah missing values: \n", Gucheng_df.isna().sum())
# Out:
# Jumlah missing values:
#  No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5         0
# PM10          0
# SO2           0
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
Gucheng_df[(Gucheng_df['NO2'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10   SO2  NO2  \
# 76        77  2013      3    4     4    7.000000   18.000000  14.0  NaN
# 172      173  2013      3    8     4  322.000000  345.000000  62.0  NaN
# 1109    1110  2013      4   16     5   50.000000  156.000000  46.0  NaN
# 1110    1111  2013      4   16     6   58.000000  185.000000  35.0  NaN
# 1111    1112  2013      4   16     7   57.000000  185.000000  35.0  NaN
# ...      ...   ...    ...  ...   ...         ...         ...   ...  ...
# 34883  34884  2017      2   21    11   82.773611  110.060391   2.0  NaN
# 34885  34886  2017      2   21    13   82.773611  110.060391   2.0  NaN
# 35027  35028  2017      2   27    11  122.000000  122.000000   2.0  NaN
# 35028  35029  2017      2   27    12   82.773611  110.060391   2.0  NaN
# 35029  35030  2017      2   27    13   82.773611  110.060391   2.0  NaN
#
#            CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
Gucheng_df.NO2.value_counts()
# Out:
# NO2
# 26.0000     408
# 42.0000     394
# 44.0000     393
# 28.0000     392
# 36.0000     391
#            ...
# 81.7094       1
# 59.9476       1
# 78.4246       1
# 76.9875       1
# 215.0000      1
# Name: count, Length: 465, dtype: int64

# %%
Gucheng_df.NO2.describe()
# Out:
# count    34041.000000
# mean        59.305833
# std         37.116200
# min          2.000000
# 25%         30.000000
# 50%         53.000000
# 75%         82.000000
# max        290.000000
# Name: NO2, dtype: float64

# %%
Gucheng_df['NO2'].fillna(value=Gucheng_df['NO2'].mean(), inplace=True)

# %%
Gucheng_df[(Gucheng_df['NO2'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Gucheng_df[(Gucheng_df['CO'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10       SO2  \
# 75        76  2013      3    4     3   12.000000   34.000000    6.0000
# 124      125  2013      3    6     4  192.000000  203.000000   83.6808
# 171      172  2013      3    8     3  324.000000  373.000000   71.0000
# 178      179  2013      3    8    10  326.000000  844.000000  125.9496
# 267      268  2013      3   12     3  117.000000  127.000000   73.0000
# ...      ...   ...    ...  ...   ...         ...         ...       ...
# 34885  34886  2017      2   21    13   82.773611  110.060391    2.0000
# 34912  34913  2017      2   22    16  131.000000  131.000000    2.0000
# 35027  35028  2017      2   27    11  122.000000  122.000000    2.0000
# 35028  35029  2017      2   27    12   82.773611  110.060391    2.0000
# 35029  35030  2017      2   27    13   82.773611  110.060391    2.0000
#
#               NO2  CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
Gucheng_df['CO'].fillna(value=Gucheng_df['CO'].mean(), inplace=True)

# %%
Gucheng_df[(Gucheng_df['CO'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Gucheng_df[(Gucheng_df['O3'].isna())]
# Out:
#           No  year  month  day  hour      PM2.5        PM10   SO2         NO2  \
# 435      436  2013      3   19     3  33.000000   41.000000  15.0   50.000000
# 436      437  2013      3   19     4  31.000000   35.000000  15.0   49.000000
# 531      532  2013      3   23     3  51.000000   70.000000  12.0   85.000000
# 578      579  2013      3   25     2  73.000000  121.000000  42.0  105.000000
# 579      580  2013      3   25     3  79.000000  140.000000  26.0   95.000000
# ...      ...   ...    ...  ...   ...        ...         ...   ...         ...
# 34883  34884  2017      2   21    11  82.773611  110.060391   2.0   59.305833
# 34885  34886  2017      2   21    13  82.773611  110.060391   2.0   59.305833
# 34913  34914  2017      2   22    17  28.000000   28.000000  11.0   17.000000
# 35028  35029  2017      2   27    12  82.773611  110.060391   2.0   59.305833
# 35029  35030  2017      2   27    13  82.773611  110.060391   2.0   59.305833
#
# ...

# %%
Gucheng_df.O3.value_counts()
# Out:
# O3
# 2.0000      4224
# 1.0000      1520
# 3.0000       582
# 4.0000       536
# 5.0000       449
#             ...
# 82.8954        1
# 95.7474        1
# 52.2648        1
# 35.1288        1
# 332.0000       1
# Name: count, Length: 831, dtype: int64

# %%
Gucheng_df.O3.fillna(value=2.0000, inplace=True)

# %%
Gucheng_df[(Gucheng_df['TEMP'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2   NO2      CO     O3  \
# 16748  16749  2015      1   27    20   26.0   42.0  12.0  78.0  1300.0    2.0
# 17263  17264  2015      2   18     7   13.0   14.0  12.0  22.0   600.0   60.0
# 31047  31048  2016      9   14    15   75.0   75.0   4.0  20.0   700.0  209.0
# 31315  31316  2016      9   25    19  168.0  168.0   2.0  77.0  1500.0   65.0
# 31316  31317  2016      9   25    20  182.0  182.0   2.0  82.0  1600.0   46.0
# 31317  31318  2016      9   25    21  137.0  146.0   2.0  44.0  1400.0  122.0
# 31318  31319  2016      9   25    22  107.0  107.0   2.0  34.0  1300.0  108.0
# 31319  31320  2016      9   25    23   95.0   95.0   2.0  38.0  1200.0   78.0
# 31320  31321  2016      9   26     0   89.0   89.0   2.0  37.0  1000.0   64.0
# 33872  33873  2017      1   10     8    8.0    8.0   4.0  34.0   300.0   45.0
# 33882  33883  2017      1   10    18    8.0   17.0   5.0  34.0   500.0   48.0
# ...

# %%
Gucheng_df = Gucheng_df.dropna(axis=0, subset=['TEMP'])

# %%
print("Jumlah missing values: \n", Gucheng_df.isna().sum())
# Out:
# Jumlah missing values:
#  No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
Gucheng_df[(Gucheng_df['wd'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO  \
# 6388    6389  2013     11   22     4   82.0   74.0  15.0   75.0  1300.0
# 11718  11719  2014      7    2     6   44.0   44.0   2.0   16.0   800.0
# 13412  13413  2014      9   10    20   56.0  141.0  13.0   81.0   700.0
# 20853  20854  2015      7   17    21   67.0   82.0   3.0   84.0  1400.0
# 23035  23036  2015     10   16    19  274.0  338.0  23.0  243.0  4000.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...    ...     ...
# 34314  34315  2017      1   28    18  246.0  266.0  63.0   82.0   300.0
# 34334  34335  2017      1   29    14   15.0   55.0   4.0    6.0   300.0
# 34560  34561  2017      2    8     0  113.0  124.0  17.0  105.0  2600.0
# 34638  34639  2017      2   11     6   15.0   24.0  16.0   71.0   600.0
# 34746  34747  2017      2   15    18  269.0  269.0  51.0  129.0  3000.0
#
#           O3    TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
Gucheng_df.wd.value_counts()
# Out:
# wd
# NE     5139
# ENE    3950
# SW     3356
# E      2608
# NNE    2445
# WSW    2212
# SSW    2098
# N      2066
# NW     1858
# ESE    1717
# NNW    1589
# SE     1341
# S      1304
# W      1171
# WNW    1101
# SSE    1022
# Name: count, dtype: int64

# %%
Gucheng_df.wd.fillna(value="NE", inplace=True)

# %%
Gucheng_df[(Gucheng_df['wd'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Gucheng_df[(Gucheng_df['PM2.5'].isna())]
Gucheng_df['PM2.5'].fillna(value=Gucheng_df['PM2.5'].mean(), inplace=True)
Gucheng_df.NO2.value_counts()
Gucheng_df[(Gucheng_df['PM2.5'].isna())]
Gucheng_df.SO2.fillna(value=2.0000, inplace=True)
print("Jumlah missing values: \n", Gucheng_df.isna().sum())
Gucheng_df[(Gucheng_df['TEMP'].isna())]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
#       2 Aotizhongxin_df['PM2.5'].fillna(value=Aotizhongxin_df['PM2.5'].mean(), inplace=True)
#       3 Aotizhongxin_df.NO2.value_counts()
#
# NameError: name 'Aotizhongxin_df' is not defined
