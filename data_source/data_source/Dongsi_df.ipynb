# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Dongsi_df = pd.read_csv("https://raw.githubusercontent.com/ortenox/data_analyst_project/main/PRSA_Data_Dongsi_20130301-20170228.csv")

# %%
Dongsi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %%
Dongsi_df.info()
print("Jumlah missing values: \n", Dongsi_df.isna().sum())
print("Jumlah duplikasi: ", Dongsi_df.duplicated().sum())
Dongsi_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# Jumlah missing values:
# ...

# %%
Dongsi_df[(Dongsi_df['PM2.5'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2   NO2      CO  \
# 616      617  2013      3   26    16    NaN    NaN   NaN   NaN     NaN
# 1092    1093  2013      4   15    12    NaN  168.0  79.0  50.0  1600.0
# 1642    1643  2013      5    8    10    NaN  169.0  93.0  64.0     NaN
# 1643    1644  2013      5    8    11    NaN  214.0  89.0  73.0  2100.0
# 2304    2305  2013      6    5     0    NaN   38.0  14.0  37.0  1300.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...   ...     ...
# 34913  34914  2017      2   22    17    NaN    6.0  10.0  44.0  1400.0
# 35030  35031  2017      2   27    14    NaN    NaN   NaN   NaN     NaN
# 35031  35032  2017      2   27    15    NaN    NaN   NaN   NaN     NaN
# 35032  35033  2017      2   27    16    NaN    NaN   NaN   NaN     NaN
# 35033  35034  2017      2   27    17    NaN    NaN   NaN   NaN     NaN
#
#             O3  TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
Dongsi_df['PM2.5'].fillna(value=Dongsi_df['PM2.5'].mean(), inplace=True)

# %%
Dongsi_df[(Dongsi_df['PM2.5'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Dongsi_df[(Dongsi_df['PM10'].isna())]
# Out:
#           No  year  month  day  hour      PM2.5  PM10      SO2      NO2  \
# 204      205  2013      3    9    12  77.000000   NaN   8.0000  23.0000
# 616      617  2013      3   26    16  86.194297   NaN      NaN      NaN
# 2345    2346  2013      6    6    17  86.194297   NaN   3.0000  78.0000
# 3251    3252  2013      7   14    11  90.000000   NaN  17.7072  33.6692
# 3497    3498  2013      7   24    17  86.194297   NaN      NaN      NaN
# ...      ...   ...    ...  ...   ...        ...   ...      ...      ...
# 34885  34886  2017      2   21    13  86.194297   NaN      NaN      NaN
# 35030  35031  2017      2   27    14  86.194297   NaN      NaN      NaN
# 35031  35032  2017      2   27    15  86.194297   NaN      NaN      NaN
# 35032  35033  2017      2   27    16  86.194297   NaN      NaN      NaN
# 35033  35034  2017      2   27    17  86.194297   NaN      NaN      NaN
#
#            CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
Dongsi_df['PM10'].fillna(value=Dongsi_df['PM10'].mean(), inplace=True)

# %%
Dongsi_df[(Dongsi_df['PM10'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Dongsi_df[(Dongsi_df['SO2'].isna())]
# Out:
#           No  year  month  day  hour      PM2.5        PM10  SO2   NO2  \
# 2          3  2013      3    1     2   7.000000    7.000000  NaN  17.0
# 98        99  2013      3    5     2  95.000000  133.000000  NaN  71.0
# 194      195  2013      3    9     2  64.000000   93.000000  NaN  76.0
# 616      617  2013      3   26    16  86.194297  110.336742  NaN   NaN
# 617      618  2013      3   26    17   3.000000    3.000000  NaN   NaN
# ...      ...   ...    ...  ...   ...        ...         ...  ...   ...
# 34890  34891  2017      2   21    18  32.000000   37.000000  NaN   NaN
# 35030  35031  2017      2   27    14  86.194297  110.336742  NaN   NaN
# 35031  35032  2017      2   27    15  86.194297  110.336742  NaN   NaN
# 35032  35033  2017      2   27    16  86.194297  110.336742  NaN   NaN
# 35033  35034  2017      2   27    17  86.194297  110.336742  NaN   NaN
#
#            CO     O3  TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
Dongsi_df.SO2.value_counts()
# Out:
# SO2
# 2.0000      6248
# 3.0000      1788
# 4.0000      1671
# 5.0000      1432
# 6.0000      1408
#             ...
# 71.4000        1
# 67.4016        1
# 38.5560        1
# 60.2616        1
# 172.0000       1
# Name: count, Length: 392, dtype: int64

# %%
Dongsi_df.SO2.fillna(value=2.0000, inplace=True)

# %%
Dongsi_df[(Dongsi_df['SO2'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
print("Jumlah missing values: \n", Dongsi_df.isna().sum())
# Out:
# Jumlah missing values:
#  No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5         0
# PM10          0
# SO2           0
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
Dongsi_df[(Dongsi_df['NO2'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10   SO2  NO2  \
# 4          5  2013      3    1     4    3.000000    3.000000   7.0  NaN
# 100      101  2013      3    5     4  115.000000  138.000000  81.0  NaN
# 196      197  2013      3    9     4   83.000000   99.000000  59.0  NaN
# 616      617  2013      3   26    16   86.194297  110.336742   2.0  NaN
# 617      618  2013      3   26    17    3.000000    3.000000   2.0  NaN
# ...      ...   ...    ...  ...   ...         ...         ...   ...  ...
# 34890  34891  2017      2   21    18   32.000000   37.000000   2.0  NaN
# 35030  35031  2017      2   27    14   86.194297  110.336742   2.0  NaN
# 35031  35032  2017      2   27    15   86.194297  110.336742   2.0  NaN
# 35032  35033  2017      2   27    16   86.194297  110.336742   2.0  NaN
# 35033  35034  2017      2   27    17   86.194297  110.336742   2.0  NaN
#
#            CO     O3  TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
Dongsi_df.NO2.value_counts()
# Out:
# NO2
# 20.0000     468
# 32.0000     456
# 30.0000     448
# 34.0000     444
# 28.0000     436
#            ...
# 139.1934      1
# 134.6768      1
# 103.2659      1
# 212.0000      1
# 203.0000      1
# Name: count, Length: 701, dtype: int64

# %%
Dongsi_df.NO2.describe()
# Out:
# count    33463.000000
# mean        53.699443
# std         33.959230
# min          2.000000
# 25%         27.000000
# 50%         47.000000
# 75%         73.000000
# max        258.000000
# Name: NO2, dtype: float64

# %%
Dongsi_df['NO2'].fillna(value=Dongsi_df['NO2'].mean(), inplace=True)

# %%
Dongsi_df[(Dongsi_df['NO2'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Dongsi_df[(Dongsi_df['CO'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10      SO2  \
# 3          4  2013      3    1     3    3.000000    3.000000   5.0000
# 74        75  2013      3    4     2   43.000000   48.000000   6.2832
# 99       100  2013      3    5     3  104.000000  136.000000  71.0000
# 178      179  2013      3    8    10  260.000000  197.000000  81.1104
# 195      196  2013      3    9     3   74.000000   98.000000  52.0000
# ...      ...   ...    ...  ...   ...         ...         ...      ...
# 34890  34891  2017      2   21    18   32.000000   37.000000   2.0000
# 35030  35031  2017      2   27    14   86.194297  110.336742   2.0000
# 35031  35032  2017      2   27    15   86.194297  110.336742   2.0000
# 35032  35033  2017      2   27    16   86.194297  110.336742   2.0000
# 35033  35034  2017      2   27    17   86.194297  110.336742   2.0000
#
#               NO2  CO     O3  TEMP    PRES  DEWP  RAIN  wd  WSPM station
# ...

# %%
Dongsi_df['CO'].fillna(value=Dongsi_df['CO'].mean(), inplace=True)

# %%
Dongsi_df[(Dongsi_df['CO'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Dongsi_df[(Dongsi_df['O3'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10      SO2  \
# 3          4  2013      3    1     3    3.000000    3.000000   5.0000
# 483      484  2013      3   21     3   85.000000   75.000000  15.0000
# 579      580  2013      3   25     3   78.000000  104.000000  23.4192
# 582      583  2013      3   25     6   68.000000   81.000000  20.0000
# 615      616  2013      3   26    15  187.000000  206.000000  69.0000
# ...      ...   ...    ...  ...   ...         ...         ...      ...
# 34889  34890  2017      2   21    17   25.000000   57.000000   2.0000
# 35030  35031  2017      2   27    14   86.194297  110.336742   2.0000
# 35031  35032  2017      2   27    15   86.194297  110.336742   2.0000
# 35032  35033  2017      2   27    16   86.194297  110.336742   2.0000
# 35033  35034  2017      2   27    17   86.194297  110.336742   2.0000
#
#              NO2           CO  O3  TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
Dongsi_df.O3.value_counts()
# Out:
# O3
# 2.0000      2950
# 3.0000       904
# 4.0000       862
# 5.0000       600
# 6.0000       541
#             ...
# 111.3840       1
# 91.0350        1
# 88.4646        1
# 93.8196        1
# 346.0000       1
# Name: count, Length: 737, dtype: int64

# %%
Dongsi_df.O3.fillna(value=2.0000, inplace=True)

# %%
Dongsi_df[(Dongsi_df['TEMP'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2   NO2      CO     O3  \
# 16748  16749  2015      1   27    20   35.0   50.0  14.0  66.0  1000.0    2.0
# 17263  17264  2015      2   18     7   12.0   12.0   8.0  24.0   400.0   50.0
# 31047  31048  2016      9   14    15   78.0   78.0   7.0  18.0   900.0  186.0
# 31315  31316  2016      9   25    19  183.0  183.0   8.0  76.0  2500.0   58.0
# 31316  31317  2016      9   25    20  143.0  143.0   7.0  42.0  1600.0  101.0
# 31317  31318  2016      9   25    21  106.0  106.0   8.0  30.0  1400.0  102.0
# 31318  31319  2016      9   25    22   95.0   95.0   6.0  32.0  1400.0   76.0
# 31319  31320  2016      9   25    23   90.0   90.0   5.0  33.0  1300.0   59.0
# 31320  31321  2016      9   26     0   88.0   88.0   5.0  40.0  1200.0   42.0
# 33872  33873  2017      1   10     8    7.0    7.0   5.0  43.0  1300.0   31.0
# 33882  33883  2017      1   10    18   15.0   15.0   9.0  36.0   700.0   68.0
# ...

# %%
Dongsi_df = Dongsi_df.dropna(axis=0, subset=['TEMP'])

# %%
print("Jumlah missing values: \n", Dongsi_df.isna().sum())
# Out:
# Jumlah missing values:
#  No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         64
# WSPM        0
# station     0
# dtype: int64

# %%
Dongsi_df = Dongsi_df.dropna(axis=0, subset=['RAIN'])

# %%
Dongsi_df[(Dongsi_df['wd'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Dongsi_df.wd.value_counts()
# Out:
# wd
# NNW    4873
# NW     3835
# N      3777
# WNW    2877
# ESE    2786
# E      2427
# NNE    1919
# SSE    1853
# SE     1816
# NE     1720
# S      1700
# W      1412
# ENE    1305
# SSW    1126
# SW      880
# WSW     704
# Name: count, dtype: int64

# %%
Dongsi_df.wd.fillna(value="NNW", inplace=True)

# %%
Dongsi_df[(Dongsi_df['wd'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
Aotizhongxin_df['PM2.5'].fillna(value=Aotizhongxin_df['PM2.5'].mean(), inplace=True)
Aotizhongxin_df.NO2.value_counts()
Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
Aotizhongxin_df.SO2.fillna(value=2.0000, inplace=True)
print("Jumlah missing values: \n", Aotizhongxin_df.isna().sum())
Aotizhongxin_df[(Aotizhongxin_df['TEMP'].isna())]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
#       2 Aotizhongxin_df['PM2.5'].fillna(value=Aotizhongxin_df['PM2.5'].mean(), inplace=True)
#       3 Aotizhongxin_df.NO2.value_counts()
#
# NameError: name 'Aotizhongxin_df' is not defined
