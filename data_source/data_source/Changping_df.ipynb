# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Changping_df = pd.read_csv("https://raw.githubusercontent.com/ortenox/data_analyst_project/main/PRSA_Data_Changping_20130301-20170228.csv")

# %%
Changping_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
Changping_df.info()
print("Jumlah missing values: \n", Changping_df.isna().sum())
print("Jumlah duplikasi: ", Changping_df.duplicated().sum())
Changping_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# Jumlah missing values:
# ...

# %%
Changping_df[(Changping_df['PM2.5'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5   PM10      SO2      NO2      CO  \
# 1308    1309  2013      4   24    12    NaN    NaN   9.0000  33.0000   400.0
# 1309    1310  2013      4   24    13    NaN  302.0   3.0000  16.0000   300.0
# 1814    1815  2013      5   15    14    NaN   70.0  46.0000  22.0000  1100.0
# 1815    1816  2013      5   15    15    NaN   71.0  39.0000  19.0000  1100.0
# 2417    2418  2013      6    9    17    NaN    NaN   5.9976  31.2056     NaN
# ...      ...   ...    ...  ...   ...    ...    ...      ...      ...     ...
# 34879  34880  2017      2   21     7    NaN    NaN      NaN      NaN     NaN
# 34880  34881  2017      2   21     8    NaN    NaN      NaN      NaN     NaN
# 34883  34884  2017      2   21    11    NaN    NaN      NaN      NaN     NaN
# 34885  34886  2017      2   21    13    NaN    NaN      NaN      NaN     NaN
# 34887  34888  2017      2   21    15    NaN    6.0      NaN  34.0000     NaN
#
# ...

# %%
Changping_df['PM2.5'].fillna(value=Changping_df['PM2.5'].mean(), inplace=True)

# %%
Changping_df[(Changping_df['PM2.5'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Changping_df[(Changping_df['PM10'].isna())]
# Out:
#           No  year  month  day  hour      PM2.5  PM10     SO2      NO2     CO  \
# 1308    1309  2013      4   24    12  71.099743   NaN  9.0000  33.0000  400.0
# 2417    2418  2013      6    9    17  71.099743   NaN  5.9976  31.2056    NaN
# 2967    2968  2013      7    2    15  11.000000   NaN  3.7128  11.2915    NaN
# 3291    3292  2013      7   16     3  23.000000   NaN  3.0000  12.0000    NaN
# 3306    3307  2013      7   16    18   4.000000   NaN  3.0000  14.0000  300.0
# ...      ...   ...    ...  ...   ...        ...   ...     ...      ...    ...
# 34877  34878  2017      2   21     5  71.099743   NaN     NaN      NaN    NaN
# 34879  34880  2017      2   21     7  71.099743   NaN     NaN      NaN    NaN
# 34880  34881  2017      2   21     8  71.099743   NaN     NaN      NaN    NaN
# 34883  34884  2017      2   21    11  71.099743   NaN     NaN      NaN    NaN
# 34885  34886  2017      2   21    13  71.099743   NaN     NaN      NaN    NaN
#
# ...

# %%
Changping_df['PM10'].fillna(value=Changping_df['PM10'].mean(), inplace=True)

# %%
Changping_df[(Changping_df['PM10'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Changping_df[(Changping_df['SO2'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10  SO2    NO2  \
# 26        27  2013      3    2     2   13.000000    9.000000  NaN   56.0
# 122      123  2013      3    6     2  146.000000  153.000000  NaN  100.0
# 1178    1179  2013      4   19     2   32.000000  164.000000  NaN   33.0
# 1274    1275  2013      4   23     2  155.000000  130.000000  NaN   49.0
# 1370    1371  2013      4   27     2   44.000000   74.000000  NaN   59.0
# ...      ...   ...    ...  ...   ...         ...         ...  ...    ...
# 34880  34881  2017      2   21     8   71.099743   94.657871  NaN    NaN
# 34883  34884  2017      2   21    11   71.099743   94.657871  NaN    NaN
# 34885  34886  2017      2   21    13   71.099743   94.657871  NaN    NaN
# 34887  34888  2017      2   21    15   71.099743    6.000000  NaN   34.0
# 35058  35059  2017      2   28    18   18.000000   57.000000  NaN    2.0
#
#            CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# ...

# %%
Changping_df.SO2.value_counts()
# Out:
# SO2
# 2.0000      9215
# 3.0000      2732
# 4.0000      1734
# 5.0000      1498
# 6.0000      1394
#             ...
# 41.9832        1
# 32.8440        1
# 23.9904        1
# 52.8360        1
# 215.0000       1
# Name: count, Length: 294, dtype: int64

# %%
Changping_df.SO2.fillna(value=2.0000, inplace=True)

# %%
Changping_df[(Changping_df['SO2'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
print("Jumlah missing values: \n", Changping_df.isna().sum())
# Out:
# Jumlah missing values:
#  No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5         0
# PM10          0
# SO2           0
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
Changping_df[(Changping_df['NO2'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10   SO2  NO2  \
# 28        29  2013      3    2     4   14.000000   18.000000  24.0  NaN
# 124      125  2013      3    6     4  149.000000  155.000000  59.0  NaN
# 1057    1058  2013      4   14     1    8.000000   12.000000   3.0  NaN
# 1061    1062  2013      4   14     5    4.000000    9.000000   3.0  NaN
# 1180    1181  2013      4   19     4   42.000000   77.000000  19.0  NaN
# ...      ...   ...    ...  ...   ...         ...         ...   ...  ...
# 34879  34880  2017      2   21     7   71.099743   94.657871   2.0  NaN
# 34880  34881  2017      2   21     8   71.099743   94.657871   2.0  NaN
# 34883  34884  2017      2   21    11   71.099743   94.657871   2.0  NaN
# 34885  34886  2017      2   21    13   71.099743   94.657871   2.0  NaN
# 34889  34890  2017      2   21    17   96.000000   96.000000   8.0  NaN
#
#            CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# ...

# %%
Changping_df.NO2.value_counts()
# Out:
# NO2
# 20.0000     684
# 24.0000     675
# 25.0000     673
# 22.0000     668
# 17.0000     661
#            ...
# 47.4243       1
# 33.0533       1
# 36.9540       1
# 36.7487       1
# 203.0000      1
# Name: count, Length: 459, dtype: int64

# %%
Changping_df.NO2.describe()
# Out:
# count    34397.000000
# mean        44.182086
# std         29.519796
# min          1.847700
# 25%         22.000000
# 50%         36.000000
# 75%         60.358200
# max        226.000000
# Name: NO2, dtype: float64

# %%
Changping_df['NO2'].fillna(value=Changping_df['NO2'].mean(), inplace=True)

# %%
Changping_df[(Changping_df['NO2'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Changping_df[(Changping_df['CO'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10      SO2  \
# 27        28  2013      3    2     3   14.000000   24.000000  23.0000
# 123      124  2013      3    6     3  170.000000  179.000000  55.0000
# 178      179  2013      3    8    10  180.000000  257.000000  59.4048
# 219      220  2013      3   10     3    3.000000    7.000000   9.0000
# 315      316  2013      3   14     3   80.000000   88.000000  23.0000
# ...      ...   ...    ...  ...   ...         ...         ...      ...
# 34880  34881  2017      2   21     8   71.099743   94.657871   2.0000
# 34883  34884  2017      2   21    11   71.099743   94.657871   2.0000
# 34885  34886  2017      2   21    13   71.099743   94.657871   2.0000
# 34887  34888  2017      2   21    15   71.099743    6.000000   2.0000
# 35058  35059  2017      2   28    18   18.000000   57.000000   2.0000
#
#              NO2  CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# ...

# %%
Changping_df['CO'].fillna(value=Changping_df['CO'].mean(), inplace=True)

# %%
Changping_df[(Changping_df['CO'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Changping_df[(Changping_df['O3'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10   SO2        NO2  \
# 27        28  2013      3    2     3   14.000000   24.000000  23.0  42.000000
# 495      496  2013      3   21    15  138.000000  146.000000  27.0  42.000000
# 507      508  2013      3   22     3    3.000000    6.000000   3.0  14.000000
# 603      604  2013      3   26     3  144.000000  195.000000  14.0  90.000000
# 699      700  2013      3   30     3   70.000000   98.000000  61.0  63.000000
# ...      ...   ...    ...  ...   ...         ...         ...   ...        ...
# 34880  34881  2017      2   21     8   71.099743   94.657871   2.0  44.182086
# 34883  34884  2017      2   21    11   71.099743   94.657871   2.0  44.182086
# 34885  34886  2017      2   21    13   71.099743   94.657871   2.0  44.182086
# 34888  34889  2017      2   21    16   78.000000   78.000000   3.0   2.000000
# 35059  35060  2017      2   28    19   28.000000   47.000000   4.0  14.000000
#
# ...

# %%
Changping_df.O3.value_counts()
# Out:
# O3
# 2.0000      2273
# 3.0000       829
# 4.0000       717
# 5.0000       584
# 6.0000       576
#             ...
# 178.8570       1
# 174.3588       1
# 193.2084       1
# 226.1952       1
# 303.0000       1
# Name: count, Length: 886, dtype: int64

# %%
Changping_df.O3.fillna(value=2.0000, inplace=True)

# %%
Changping_df[(Changping_df['TEMP'].isna())]

# %%
Changping_df = Changping_df.dropna(axis=0, subset=['TEMP'])

# %%
print("Jumlah missing values: \n", Changping_df.isna().sum())

# %%
Changping_df[(Changping_df['wd'].isna())]

# %%
Changping_df.wd.value_counts()

# %%
Changping_df.wd.fillna(value="NNW", inplace=True)

# %%
Changping_df[(Changping_df['wd'].isna())]

# %%
Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
Aotizhongxin_df['PM2.5'].fillna(value=Aotizhongxin_df['PM2.5'].mean(), inplace=True)
Aotizhongxin_df.NO2.value_counts()
Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
Aotizhongxin_df.SO2.fillna(value=2.0000, inplace=True)
print("Jumlah missing values: \n", Aotizhongxin_df.isna().sum())
Aotizhongxin_df[(Aotizhongxin_df['TEMP'].isna())]
