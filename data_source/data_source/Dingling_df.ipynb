# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Dingling_df = pd.read_csv("https://raw.githubusercontent.com/ortenox/data_analyst_project/main/PRSA_Data_Dingling_20130301-20170228.csv")

# %%
Dingling_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %%
Dingling_df.info()
print("Jumlah missing values: \n", Dingling_df.isna().sum())
print("Jumlah duplikasi: ", Dingling_df.duplicated().sum())
Dingling_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# Jumlah missing values:
# ...

# %%
Dingling_df[(Dingling_df['PM2.5'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2  CO   O3  TEMP  \
# 752      753  2013      4    1     8    NaN   NaN   NaN   NaN NaN  NaN  11.0
# 753      754  2013      4    1     9    NaN   NaN   NaN   NaN NaN  NaN  10.6
# 754      755  2013      4    1    10    NaN   NaN   NaN   NaN NaN  NaN  13.2
# 755      756  2013      4    1    11    NaN   NaN   NaN   NaN NaN  NaN  13.8
# 756      757  2013      4    1    12    NaN   NaN   NaN   NaN NaN  NaN  15.3
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...  ..  ...   ...
# 34863  34864  2017      2   20    15    NaN   NaN   NaN   NaN NaN  NaN   4.2
# 34864  34865  2017      2   20    16    NaN   NaN   NaN   NaN NaN  NaN   4.4
# 34866  34867  2017      2   20    18    NaN   NaN   NaN   NaN NaN  NaN   3.3
# 34883  34884  2017      2   21    11    NaN   NaN  26.0  68.0 NaN  5.0  -0.5
# 34885  34886  2017      2   21    13    NaN   NaN   NaN   NaN NaN  NaN  -1.0
#
# ...

# %%
Dingling_df['PM2.5'].fillna(value=Dingling_df['PM2.5'].mean(), inplace=True)

# %%
Dingling_df[(Dingling_df['PM2.5'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Dingling_df[(Dingling_df['PM10'].isna())]
# Out:
#           No  year  month  day  hour      PM2.5  PM10   SO2   NO2     CO  \
# 10        11  2013      3    1    10   8.000000   NaN   3.0   NaN  200.0
# 12        13  2013      3    1    12   6.000000   NaN   3.0   NaN  200.0
# 77        78  2013      3    4     5   5.000000   NaN   3.0   NaN  200.0
# 226      227  2013      3   10    10   7.000000   NaN  10.0   7.0  300.0
# 227      228  2013      3   10    11  12.000000   NaN   9.0   6.0  300.0
# ...      ...   ...    ...  ...   ...        ...   ...   ...   ...    ...
# 34863  34864  2017      2   20    15  65.989497   NaN   NaN   NaN    NaN
# 34864  34865  2017      2   20    16  65.989497   NaN   NaN   NaN    NaN
# 34866  34867  2017      2   20    18  65.989497   NaN   NaN   NaN    NaN
# 34883  34884  2017      2   21    11  65.989497   NaN  26.0  68.0    NaN
# 34885  34886  2017      2   21    13  65.989497   NaN   NaN   NaN    NaN
#
#          O3  TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# ...

# %%
Dingling_df['PM10'].fillna(value=Dingling_df['PM10'].mean(), inplace=True)

# %%
Dingling_df[(Dingling_df['PM10'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Dingling_df[(Dingling_df['SO2'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10  SO2   NO2  \
# 50        51  2013      3    3     2   52.000000   53.000000  NaN  69.0
# 146      147  2013      3    7     2  150.000000  149.000000  NaN  74.0
# 752      753  2013      4    1     8   65.989497   83.739723  NaN   NaN
# 753      754  2013      4    1     9   65.989497   83.739723  NaN   NaN
# 754      755  2013      4    1    10   65.989497   83.739723  NaN   NaN
# ...      ...   ...    ...  ...   ...         ...         ...  ...   ...
# 34864  34865  2017      2   20    16   65.989497   83.739723  NaN   NaN
# 34866  34867  2017      2   20    18   65.989497   83.739723  NaN   NaN
# 34884  34885  2017      2   21    12   62.000000   62.000000  NaN  53.0
# 34885  34886  2017      2   21    13   65.989497   83.739723  NaN   NaN
# 35056  35057  2017      2   28    16   14.000000   30.000000  NaN   6.0
#
#            CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# ...

# %%
Dingling_df.SO2.value_counts()
# Out:
# SO2
# 2.0000      9638
# 3.0000      3766
# 4.0000      1833
# 5.0000      1425
# 6.0000      1280
#             ...
# 60.8328        1
# 59.6904        1
# 55.1208        1
# 37.6992        1
# 156.0000       1
# Name: count, Length: 327, dtype: int64

# %%
Dingling_df.SO2.fillna(value=2.0000, inplace=True)

# %%
Dingling_df[(Dingling_df['SO2'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
print("Jumlah missing values: \n", Dingling_df.isna().sum())
# Out:
# Jumlah missing values:
#  No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5         0
# PM10          0
# SO2           0
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
Dingling_df[(Dingling_df['NO2'].isna())]
# Out:
#           No  year  month  day  hour      PM2.5       PM10  SO2  NO2     CO  \
# 0          1  2013      3    1     0   4.000000   4.000000  3.0  NaN  200.0
# 1          2  2013      3    1     1   7.000000   7.000000  3.0  NaN  200.0
# 3          4  2013      3    1     3   6.000000   6.000000  3.0  NaN  200.0
# 4          5  2013      3    1     4   5.000000   5.000000  3.0  NaN  200.0
# 10        11  2013      3    1    10   8.000000  83.739723  3.0  NaN  200.0
# ...      ...   ...    ...  ...   ...        ...        ...  ...  ...    ...
# 34863  34864  2017      2   20    15  65.989497  83.739723  2.0  NaN    NaN
# 34864  34865  2017      2   20    16  65.989497  83.739723  2.0  NaN    NaN
# 34866  34867  2017      2   20    18  65.989497  83.739723  2.0  NaN    NaN
# 34885  34886  2017      2   21    13  65.989497  83.739723  2.0  NaN    NaN
# 35055  35056  2017      2   28    15  16.000000  27.000000  6.0  NaN  400.0
#
# ...

# %%
Dingling_df.NO2.value_counts()
# Out:
# NO2
# 2.0000      2841
# 5.0000       930
# 8.0000       915
# 7.0000       894
# 10.0000      891
#             ...
# 90.1267        1
# 53.9939        1
# 125.2330       1
# 77.6034        1
# 190.0000       1
# Name: count, Length: 636, dtype: int64

# %%
Dingling_df.NO2.describe()
# Out:
# count    33830.000000
# mean        27.585467
# std         26.383882
# min          1.026500
# 25%          9.000000
# 50%         19.000000
# 75%         38.000000
# max        205.000000
# Name: NO2, dtype: float64

# %%
Dingling_df['NO2'].fillna(value=Dingling_df['NO2'].mean(), inplace=True)

# %%
Dingling_df[(Dingling_df['NO2'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Dingling_df[(Dingling_df['CO'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10      SO2  \
# 51        52  2013      3    3     3   57.000000   57.000000  20.0000
# 147      148  2013      3    7     3   91.000000   85.000000  32.0000
# 178      179  2013      3    8    10  122.000000  175.000000  31.7016
# 243      244  2013      3   11     3   75.000000   83.000000  18.0000
# 252      253  2013      3   11    12  113.000000  153.000000  58.0000
# ...      ...   ...    ...  ...   ...         ...         ...      ...
# 34866  34867  2017      2   20    18   65.989497   83.739723   2.0000
# 34883  34884  2017      2   21    11   65.989497   83.739723  26.0000
# 34884  34885  2017      2   21    12   62.000000   62.000000   2.0000
# 34885  34886  2017      2   21    13   65.989497   83.739723   2.0000
# 35056  35057  2017      2   28    16   14.000000   30.000000   2.0000
#
#              NO2  CO     O3  TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# ...

# %%
Dingling_df['CO'].fillna(value=Dingling_df['CO'].mean(), inplace=True)

# %%
Dingling_df[(Dingling_df['CO'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Dingling_df[(Dingling_df['O3'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10   SO2        NO2  \
# 435      436  2013      3   19     3   40.000000   20.000000   4.0  28.000000
# 531      532  2013      3   23     3   56.000000   71.000000  12.0  64.000000
# 627      628  2013      3   27     3  225.000000  221.000000  29.0  66.000000
# 723      724  2013      3   31     3  118.000000  104.000000  14.0  61.000000
# 750      751  2013      4    1     6  229.000000  235.000000  25.0  46.000000
# ...      ...   ...    ...  ...   ...         ...         ...   ...        ...
# 34864  34865  2017      2   20    16   65.989497   83.739723   2.0  27.585467
# 34866  34867  2017      2   20    18   65.989497   83.739723   2.0  27.585467
# 34884  34885  2017      2   21    12   62.000000   62.000000   2.0  53.000000
# 34885  34886  2017      2   21    13   65.989497   83.739723   2.0  27.585467
# 34933  34934  2017      2   23    13    6.000000    6.000000   4.0   2.000000
#
# ...

# %%
Dingling_df.O3.value_counts()
# Out:
# O3
# 2.0000      1798
# 69.0000      344
# 56.0000      341
# 54.0000      336
# 68.0000      335
#             ...
# 295.3818       1
# 67.9014        1
# 74.9700        1
# 77.7546        1
# 300.0000       1
# Name: count, Length: 792, dtype: int64

# %%
Dingling_df.O3.fillna(value=2.0000, inplace=True)

# %%
Dingling_df[(Dingling_df['TEMP'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2   NO2      CO     O3  \
# 16748  16749  2015      1   27    20   39.0   43.0  28.0  34.0  1100.0   23.0
# 16813  16814  2015      1   30    13   15.0   19.0  19.0   5.0   400.0   68.0
# 16829  16830  2015      1   31     5    5.0   11.0  32.0   8.0   400.0   60.0
# 16873  16874  2015      2    2     1   60.0   60.0  30.0  39.0  2600.0    9.0
# 16883  16884  2015      2    2    11  138.0  138.0  52.0  73.0  2200.0   14.0
# 16930  16931  2015      2    4    10    8.0    8.0  13.0   5.0   200.0   69.0
# 16933  16934  2015      2    4    13   13.0   16.0  14.0   3.0   300.0   68.0
# 17007  17008  2015      2    7    15    3.0   24.0   2.0   2.0   200.0   88.0
# 17030  17031  2015      2    8    14    4.0    5.0   7.0   2.0   200.0   80.0
# 17052  17053  2015      2    9    12   87.0   87.0  82.0  53.0  1600.0   27.0
# 17053  17054  2015      2    9    13   95.0   95.0  77.0  55.0  1600.0   31.0
# ...

# %%
Dingling_df = Dingling_df.dropna(axis=0, subset=['TEMP'])

# %%
print("Jumlah missing values: \n", Dingling_df.isna().sum())
# Out:
# Jumlah missing values:
#  No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       1
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
Dingling_df[(Dingling_df['wd'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO  \
# 5107    5108  2013      9   29    19  224.0  173.0   6.0   50.0  1200.0
# 5110    5111  2013      9   29    22  141.0   91.0   4.0   41.0  1200.0
# 5111    5112  2013      9   29    23  131.0   92.0   4.0   16.0  1200.0
# 6389    6390  2013     11   22     5   34.0   64.0  22.0   44.0   800.0
# 6411    6412  2013     11   23     3   98.0  111.0  31.0  103.0  1500.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...    ...     ...
# 34296  34297  2017      1   28     0   98.0  116.0  23.0   42.0  1100.0
# 34447  34448  2017      2    3     7   70.0   78.0  28.0   52.0  1800.0
# 34519  34520  2017      2    6     7    9.0    9.0   2.0    2.0   200.0
# 34538  34539  2017      2    7     2   33.0   33.0   9.0   26.0   900.0
# 34873  34874  2017      2   21     1   51.0   63.0  17.0   25.0  1400.0
#
#             O3   TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# ...

# %%
Dingling_df.wd.value_counts()
# Out:
# wd
# NNW    4776
# NW     3835
# N      3777
# WNW    2877
# ESE    2786
# E      2427
# NNE    1919
# SSE    1853
# SE     1816
# NE     1721
# S      1700
# W      1412
# ENE    1305
# SSW    1126
# SW      880
# WSW     704
# Name: count, dtype: int64

# %%
Dingling_df.wd.fillna(value="NNW", inplace=True)

# %%
Dingling_df[(Dingling_df['wd'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
Aotizhongxin_df['PM2.5'].fillna(value=Aotizhongxin_df['PM2.5'].mean(), inplace=True)
Aotizhongxin_df.NO2.value_counts()
Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
Aotizhongxin_df.SO2.fillna(value=2.0000, inplace=True)
print("Jumlah missing values: \n", Aotizhongxin_df.isna().sum())
Aotizhongxin_df[(Aotizhongxin_df['TEMP'].isna())]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
#       2 Aotizhongxin_df['PM2.5'].fillna(value=Aotizhongxin_df['PM2.5'].mean(), inplace=True)
#       3 Aotizhongxin_df.NO2.value_counts()
#
# NameError: name 'Aotizhongxin_df' is not defined
