# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Nongzhanguan_df = pd.read_csv("https://raw.githubusercontent.com/ortenox/data_analyst_project/main/PRSA_Data_Nongzhanguan_20130301-20170228.csv")

# %%
Nongzhanguan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %%
Nongzhanguan_df.info()
print("Jumlah missing values: \n", Nongzhanguan_df.isna().sum())
print("Jumlah duplikasi: ", Nongzhanguan_df.duplicated().sum())
Nongzhanguan_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# Jumlah missing values:
# ...

# %%
Nongzhanguan_df[(Nongzhanguan_df['PM2.5'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO    O3  \
# 1258    1259  2013      4   22    10    NaN  175.0  49.0   68.0  1100.0  33.0
# 1259    1260  2013      4   22    11    NaN  205.0  51.0   70.0  1200.0  50.0
# 1260    1261  2013      4   22    12    NaN  196.0  57.0   62.0  1300.0  55.0
# 1331    1332  2013      4   25    11    NaN   73.0   3.0   23.0   400.0  90.0
# 1620    1621  2013      5    7    12    NaN    NaN  46.0  109.0  2200.0  25.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...    ...     ...   ...
# 35026  35027  2017      2   27    10    NaN    NaN   NaN    NaN     NaN   NaN
# 35029  35030  2017      2   27    13    NaN    6.0  40.0   93.0   200.0  32.0
# 35042  35043  2017      2   28     2    NaN    NaN   NaN    NaN     NaN   NaN
# 35054  35055  2017      2   28    14    NaN    6.0   2.0   10.0   200.0  94.0
# 35055  35056  2017      2   28    15    NaN    8.0   3.0   11.0   200.0  91.0
#
# ...

# %%
Nongzhanguan_df['PM2.5'].fillna(value=Nongzhanguan_df['PM2.5'].mean(), inplace=True)

# %%
Nongzhanguan_df[(Nongzhanguan_df['PM2.5'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Nongzhanguan_df[(Nongzhanguan_df['PM10'].isna())]
# Out:
#           No  year  month  day  hour      PM2.5  PM10      SO2       NO2  \
# 294      295  2013      3   13     6  13.000000   NaN  15.0000   43.0000
# 915      916  2013      4    8     3  27.000000   NaN  10.0000   38.0000
# 1620    1621  2013      5    7    12  84.838483   NaN  46.0000  109.0000
# 2411    2412  2013      6    9    11  84.838483   NaN   2.2848   22.7883
# 2476    2477  2013      6   12     4  26.000000   NaN   3.0000   26.0000
# ...      ...   ...    ...  ...   ...        ...   ...      ...       ...
# 34958  34959  2017      2   24    14  84.838483   NaN      NaN       NaN
# 34986  34987  2017      2   25    18  84.838483   NaN      NaN       NaN
# 35006  35007  2017      2   26    14  84.838483   NaN      NaN       NaN
# 35026  35027  2017      2   27    10  84.838483   NaN      NaN       NaN
# 35042  35043  2017      2   28     2  84.838483   NaN      NaN       NaN
#
#            CO       O3  TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
Nongzhanguan_df['PM10'].fillna(value=Nongzhanguan_df['PM10'].mean(), inplace=True)

# %%
Nongzhanguan_df[(Nongzhanguan_df['PM10'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Nongzhanguan_df[(Nongzhanguan_df['SO2'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10  SO2    NO2  \
# 26        27  2013      3    2     2    3.000000    9.000000  NaN   38.0
# 122      123  2013      3    6     2  184.000000  214.000000  NaN  158.0
# 1178    1179  2013      4   19     2   54.000000  130.000000  NaN   66.0
# 1274    1275  2013      4   23     2  106.000000  108.000000  NaN   44.0
# 1370    1371  2013      4   27     2   46.000000  115.000000  NaN   94.0
# ...      ...   ...    ...  ...   ...         ...         ...  ...    ...
# 34958  34959  2017      2   24    14   84.838483  108.991096  NaN    NaN
# 34986  34987  2017      2   25    18   84.838483  108.991096  NaN    NaN
# 35006  35007  2017      2   26    14   84.838483  108.991096  NaN    NaN
# 35026  35027  2017      2   27    10   84.838483  108.991096  NaN    NaN
# 35042  35043  2017      2   28     2   84.838483  108.991096  NaN    NaN
#
#            CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
Nongzhanguan_df.SO2.value_counts()
# Out:
# SO2
# 2.0000      6289
# 3.0000      2523
# 4.0000      1878
# 5.0000      1550
# 6.0000      1459
#             ...
# 80.5392        1
# 89.6784        1
# 101.3880       1
# 125.0928       1
# 257.0000       1
# Name: count, Length: 263, dtype: int64

# %%
Nongzhanguan_df.SO2.fillna(value=2.0000, inplace=True)

# %%
Nongzhanguan_df[(Nongzhanguan_df['SO2'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
print("Jumlah missing values: \n", Nongzhanguan_df.isna().sum())
# Out:
# Jumlah missing values:
#  No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5         0
# PM10          0
# SO2           0
# NO2         692
# CO         1206
# O3          506
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
Nongzhanguan_df[(Nongzhanguan_df['NO2'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10   SO2  NO2  \
# 28        29  2013      3    2     4    3.000000    6.000000   7.0  NaN
# 124      125  2013      3    6     4  153.000000  175.000000  87.0  NaN
# 1084    1085  2013      4   15     4   52.000000  155.000000  21.0  NaN
# 1180    1181  2013      4   19     4   67.000000  105.000000  39.0  NaN
# 1276    1277  2013      4   23     4   85.000000  101.000000  15.0  NaN
# ...      ...   ...    ...  ...   ...         ...         ...   ...  ...
# 34959  34960  2017      2   24    15   14.000000   29.000000   7.0  NaN
# 34986  34987  2017      2   25    18   84.838483  108.991096   2.0  NaN
# 35006  35007  2017      2   26    14   84.838483  108.991096   2.0  NaN
# 35026  35027  2017      2   27    10   84.838483  108.991096   2.0  NaN
# 35042  35043  2017      2   28     2   84.838483  108.991096   2.0  NaN
#
#            CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
Nongzhanguan_df.NO2.value_counts()
# Out:
# NO2
# 26.0000     470
# 30.0000     470
# 32.0000     467
# 22.0000     452
# 28.0000     447
#            ...
# 83.1465       1
# 77.8087       1
# 65.9013       1
# 72.8815       1
# 204.0000      1
# Name: count, Length: 595, dtype: int64

# %%
Nongzhanguan_df.NO2.describe()
# Out:
# count    34372.000000
# mean        58.097172
# std         36.297740
# min          2.000000
# 25%         29.000000
# 50%         51.000000
# 75%         80.000000
# max        273.000000
# Name: NO2, dtype: float64

# %%
Nongzhanguan_df['NO2'].fillna(value=Nongzhanguan_df['NO2'].mean(), inplace=True)

# %%
Nongzhanguan_df[(Nongzhanguan_df['NO2'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Nongzhanguan_df[(Nongzhanguan_df['CO'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10     SO2  \
# 27        28  2013      3    2     3    3.000000    6.000000    8.00
# 123      124  2013      3    6     3  169.000000  190.000000  107.00
# 178      179  2013      3    8    10  216.000000  233.000000   78.54
# 219      220  2013      3   10     3   16.000000   32.000000    8.00
# 315      316  2013      3   14     3   72.000000   56.000000   26.00
# ...      ...   ...    ...  ...   ...         ...         ...     ...
# 34958  34959  2017      2   24    14   84.838483  108.991096    2.00
# 34986  34987  2017      2   25    18   84.838483  108.991096    2.00
# 35006  35007  2017      2   26    14   84.838483  108.991096    2.00
# 35026  35027  2017      2   27    10   84.838483  108.991096    2.00
# 35042  35043  2017      2   28     2   84.838483  108.991096    2.00
#
#               NO2  CO     O3  TEMP    PRES  DEWP  RAIN   wd  WSPM  \
# 27      30.000000 NaN   89.0  -3.1  1032.6 -15.8   0.0    N   0.0
# ...

# %%
Nongzhanguan_df['CO'].fillna(value=Nongzhanguan_df['CO'].mean(), inplace=True)

# %%
Nongzhanguan_df[(Nongzhanguan_df['CO'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Nongzhanguan_df[(Nongzhanguan_df['O3'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10   SO2  \
# 507      508  2013      3   22     3   80.000000  144.000000  26.0
# 603      604  2013      3   26     3  129.000000  160.000000  75.0
# 699      700  2013      3   30     3   66.000000   97.000000  68.0
# 795      796  2013      4    3     3  156.000000  239.000000  32.0
# 891      892  2013      4    7     3   54.000000   73.000000  18.0
# ...      ...   ...    ...  ...   ...         ...         ...   ...
# 34959  34960  2017      2   24    15   14.000000   29.000000   7.0
# 34986  34987  2017      2   25    18   84.838483  108.991096   2.0
# 35006  35007  2017      2   26    14   84.838483  108.991096   2.0
# 35026  35027  2017      2   27    10   84.838483  108.991096   2.0
# 35042  35043  2017      2   28     2   84.838483  108.991096   2.0
#
#               NO2           CO  O3  TEMP    PRES  DEWP  RAIN   wd  WSPM  \
# 507     54.000000  1324.350198 NaN   4.5  1011.8  -6.1   0.0  NNW   1.5
# ...

# %%
Nongzhanguan_df.O3.value_counts()
# Out:
# O3
# 2.0000      3148
# 4.0000       872
# 3.0000       864
# 5.0000       655
# 6.0000       582
#             ...
# 71.5428        1
# 75.8268        1
# 125.0928       1
# 37.0566        1
# 390.0000       1
# Name: count, Length: 732, dtype: int64

# %%
Nongzhanguan_df.O3.fillna(value=2.0000, inplace=True)

# %%
Nongzhanguan_df[(Nongzhanguan_df['TEMP'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2   NO2      CO     O3  \
# 16748  16749  2015      1   27    20   36.0   53.0  15.0  79.0  1000.0    5.0
# 17263  17264  2015      2   18     7   12.0   13.0  19.0  28.0   500.0   53.0
# 31047  31048  2016      9   14    15   74.0   74.0   8.0  18.0   700.0  208.0
# 31315  31316  2016      9   25    19  168.0  180.0   9.0  53.0  2500.0   84.0
# 31316  31317  2016      9   25    20  137.0  173.0   8.0  31.0  1600.0  132.0
# 31317  31318  2016      9   25    21  112.0  128.0   7.0  27.0  1500.0  118.0
# 31318  31319  2016      9   25    22   94.0  108.0   6.0  27.0  1400.0   87.0
# 31319  31320  2016      9   25    23   85.0  102.0   5.0  28.0  1200.0   68.0
# 31320  31321  2016      9   26     0   80.0   90.0   5.0  31.0  1100.0   53.0
# 33872  33873  2017      1   10     8    5.0    6.0   4.0  43.0   400.0   26.0
# 33882  33883  2017      1   10    18    8.0   12.0   4.0  39.0   400.0   35.0
# ...

# %%
Nongzhanguan_df = Nongzhanguan_df.dropna(axis=0, subset=['TEMP'])

# %%
print("Jumlah missing values: \n", Nongzhanguan_df.isna().sum())
# Out:
# Jumlah missing values:
#  No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         64
# WSPM        0
# station     0
# dtype: int64

# %%
Nongzhanguan_df[(Nongzhanguan_df['wd'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO    O3  \
# 20853  20854  2015      7   17    21   53.0   63.0   4.0   48.0  1300.0  90.0
# 23035  23036  2015     10   16    19  285.0  285.0  26.0  138.0  2600.0  91.0
# 23059  23060  2015     10   17    19  354.0  354.0  16.0  184.0  2700.0  29.0
# 23356  23357  2015     10   30     4   10.0   16.0   5.0   54.0   400.0   4.0
# 25756  25757  2016      2    7     4   65.0   65.0  30.0   78.0  2000.0  10.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...    ...     ...   ...
# 34314  34315  2017      1   28    18  220.0  260.0  50.0   54.0  2700.0  18.0
# 34334  34335  2017      1   29    14   12.0   39.0   4.0    8.0   300.0  68.0
# 34560  34561  2017      2    8     0  106.0  115.0  14.0   74.0  1900.0   3.0
# 34638  34639  2017      2   11     6    9.0   14.0   6.0   39.0   400.0  33.0
# 34746  34747  2017      2   15    18  252.0  252.0  48.0  125.0  2000.0  38.0
#
# ...

# %%
Nongzhanguan_df.wd.value_counts()
# Out:
# wd
# ENE    3861
# E      3564
# NE     3539
# ESE    2706
# SW     2478
# NW     2464
# SSW    1953
# NNE    1928
# SE     1880
# N      1865
# WSW    1769
# NNW    1693
# S      1547
# SSE    1402
# WNW    1347
# W       984
# Name: count, dtype: int64

# %%
Nongzhanguan_df.wd.fillna(value="ENE", inplace=True)

# %%
Nongzhanguan_df[(Nongzhanguan_df['wd'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
Aotizhongxin_df['PM2.5'].fillna(value=Aotizhongxin_df['PM2.5'].mean(), inplace=True)
Aotizhongxin_df.NO2.value_counts()
Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
Aotizhongxin_df.SO2.fillna(value=2.0000, inplace=True)
print("Jumlah missing values: \n", Aotizhongxin_df.isna().sum())
Aotizhongxin_df[(Aotizhongxin_df['TEMP'].isna())]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
#       2 Aotizhongxin_df['PM2.5'].fillna(value=Aotizhongxin_df['PM2.5'].mean(), inplace=True)
#       3 Aotizhongxin_df.NO2.value_counts()
#
# NameError: name 'Aotizhongxin_df' is not defined
