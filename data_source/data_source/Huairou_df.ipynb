# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Huairou_df = pd.read_csv("https://raw.githubusercontent.com/ortenox/data_analyst_project/main/PRSA_Data_Huairou_20130301-20170228.csv")

# %%
Huairou_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %%
Huairou_df.info()
print("Jumlah missing values: \n", Huairou_df.isna().sum())
print("Jumlah duplikasi: ", Huairou_df.duplicated().sum())
Huairou_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# Jumlah missing values:
# ...

# %%
Huairou_df[(Huairou_df['PM2.5'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2   NO2      CO    O3  \
# 91        92  2013      3    4    19    NaN   53.0  23.0  79.0   700.0  18.0
# 92        93  2013      3    4    20    NaN   92.0  30.0  90.0  1000.0   8.0
# 93        94  2013      3    4    21    NaN  100.0  24.0  54.0  1000.0  25.0
# 94        95  2013      3    4    22    NaN   85.0  22.0  54.0   900.0  21.0
# 95        96  2013      3    4    23    NaN   74.0  18.0  47.0   900.0  91.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...   ...     ...   ...
# 34879  34880  2017      2   21     7    NaN    NaN   NaN   NaN     NaN   NaN
# 34880  34881  2017      2   21     8    NaN    NaN   NaN   NaN     NaN   NaN
# 34883  34884  2017      2   21    11    NaN    NaN   NaN   NaN     NaN   NaN
# 34885  34886  2017      2   21    13    NaN    NaN   NaN   NaN     NaN   NaN
# 34934  34935  2017      2   23    14    NaN    6.0   NaN  11.0     NaN  99.0
#
# ...

# %%
Huairou_df['PM2.5'].fillna(value=Huairou_df['PM2.5'].mean(), inplace=True)

# %%
Huairou_df[(Huairou_df['PM2.5'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Huairou_df[(Huairou_df['PM10'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5  PM10     SO2       NO2  \
# 162      163  2013      3    7    18  350.000000   NaN  67.000  199.0000
# 163      164  2013      3    7    19  363.000000   NaN  57.000  198.0000
# 636      637  2013      3   27    12    3.000000   NaN  25.000       NaN
# 1327    1328  2013      4   25     7   14.000000   NaN   3.000    9.0000
# 1330    1331  2013      4   25    10   69.626367   NaN   1.428    3.4901
# ...      ...   ...    ...  ...   ...         ...   ...     ...       ...
# 34877  34878  2017      2   21     5   69.626367   NaN     NaN       NaN
# 34879  34880  2017      2   21     7   69.626367   NaN     NaN       NaN
# 34880  34881  2017      2   21     8   69.626367   NaN     NaN       NaN
# 34883  34884  2017      2   21    11   69.626367   NaN     NaN       NaN
# 34885  34886  2017      2   21    13   69.626367   NaN     NaN       NaN
#
#            CO        O3  TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# ...

# %%
Huairou_df['PM10'].fillna(value=Huairou_df['PM10'].mean(), inplace=True)

# %%
Huairou_df[(Huairou_df['PM10'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Huairou_df[(Huairou_df['SO2'].isna())]
# Out:
#           No  year  month  day  hour      PM2.5      PM10  SO2      NO2  \
# 2          3  2013      3    1     2   4.000000   4.00000  NaN      NaN
# 98        99  2013      3    5     2  69.626367  51.00000  NaN  27.0000
# 194      195  2013      3    9     2  51.000000  72.00000  NaN  31.0000
# 999     1000  2013      4   11    15  69.626367  18.00000  NaN  70.2126
# 1154    1155  2013      4   18     2   9.000000  20.00000  NaN      NaN
# ...      ...   ...    ...  ...   ...        ...       ...  ...      ...
# 34879  34880  2017      2   21     7  69.626367  91.48269  NaN      NaN
# 34880  34881  2017      2   21     8  69.626367  91.48269  NaN      NaN
# 34883  34884  2017      2   21    11  69.626367  91.48269  NaN      NaN
# 34885  34886  2017      2   21    13  69.626367  91.48269  NaN      NaN
# 34934  34935  2017      2   23    14  69.626367   6.00000  NaN  11.0000
#
#            CO       O3  TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# ...

# %%
Huairou_df.SO2.value_counts()
# Out:
# SO2
# 2.0000      11723
# 3.0000       3558
# 4.0000       1814
# 5.0000       1449
# 6.0000       1286
#             ...
# 105.3864        1
# 28.8456         1
# 79.6824         1
# 180.0000        1
# 3.8000          1
# Name: count, Length: 247, dtype: int64

# %%
Huairou_df.SO2.fillna(value=2.0000, inplace=True)

# %%
Huairou_df[(Huairou_df['SO2'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
print("Jumlah missing values: \n", Huairou_df.isna().sum())
# Out:
# Jumlah missing values:
#  No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5         0
# PM10          0
# SO2           0
# NO2        1639
# CO         1422
# O3         1151
# TEMP         51
# PRES         53
# DEWP         53
# RAIN         55
# wd          302
# WSPM         49
# station       0
# dtype: int64

# %%
Huairou_df[(Huairou_df['NO2'].isna())]
# Out:
#           No  year  month  day  hour      PM2.5      PM10   SO2  NO2     CO  \
# 1          2  2013      3    1     1   4.000000   4.00000   3.0  NaN  100.0
# 2          3  2013      3    1     2   4.000000   4.00000   2.0  NaN  100.0
# 4          5  2013      3    1     4   3.000000   3.00000   7.0  NaN  300.0
# 11        12  2013      3    1    11  10.000000  11.00000   3.0  NaN  300.0
# 69        70  2013      3    3    21  18.000000  52.00000  10.0  NaN  300.0
# ...      ...   ...    ...  ...   ...        ...       ...   ...  ...    ...
# 34879  34880  2017      2   21     7  69.626367  91.48269   2.0  NaN    NaN
# 34880  34881  2017      2   21     8  69.626367  91.48269   2.0  NaN    NaN
# 34883  34884  2017      2   21    11  69.626367  91.48269   2.0  NaN    NaN
# 34885  34886  2017      2   21    13  69.626367  91.48269   2.0  NaN    NaN
# 34936  34937  2017      2   23    16  11.000000  12.00000   3.0  NaN  300.0
#
# ...

# %%
Huairou_df.NO2.value_counts()
# Out:
# NO2
# 2.0000      1036
# 6.0000       796
# 11.0000      796
# 8.0000       795
# 12.0000      777
#             ...
# 42.9077        1
# 25.2519        1
# 19.2982        1
# 17.6558        1
# 174.0000       1
# Name: count, Length: 296, dtype: int64

# %%
Huairou_df.NO2.describe()
# Out:
# count    33425.000000
# mean        32.497250
# std         26.489531
# min          1.026500
# 25%         12.000000
# 50%         25.000000
# 75%         46.000000
# max        231.000000
# Name: NO2, dtype: float64

# %%
Huairou_df['NO2'].fillna(value=Huairou_df['NO2'].mean(), inplace=True)

# %%
Huairou_df[(Huairou_df['NO2'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Huairou_df[(Huairou_df['CO'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5       PM10       SO2  \
# 3          4  2013      3    1     3    3.000000    3.00000    3.0000
# 29        30  2013      3    2     5   15.000000   18.00000   42.2688
# 99       100  2013      3    5     3   69.626367   51.00000   13.0000
# 110      111  2013      3    5    14   69.626367  146.00000   84.0000
# 178      179  2013      3    8    10  173.000000  193.00000  105.3864
# ...      ...   ...    ...  ...   ...         ...        ...       ...
# 34879  34880  2017      2   21     7   69.626367   91.48269    2.0000
# 34880  34881  2017      2   21     8   69.626367   91.48269    2.0000
# 34883  34884  2017      2   21    11   69.626367   91.48269    2.0000
# 34885  34886  2017      2   21    13   69.626367   91.48269    2.0000
# 34934  34935  2017      2   23    14   69.626367    6.00000    2.0000
#
#             NO2  CO       O3  TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# ...

# %%
Huairou_df['CO'].fillna(value=Huairou_df['CO'].mean(), inplace=True)

# %%
Huairou_df[(Huairou_df['CO'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Huairou_df[(Huairou_df['O3'].isna())]
# Out:
#           No  year  month  day  hour      PM2.5      PM10      SO2       NO2  \
# 3          4  2013      3    1     3   3.000000   3.00000   3.0000   2.00000
# 483      484  2013      3   21     3  85.000000  91.00000   4.0000  63.00000
# 579      580  2013      3   25     3  44.000000  99.00000  10.8528  32.49725
# 675      676  2013      3   29     3  20.000000  36.00000   8.0000  26.00000
# 771      772  2013      4    2     3   3.000000  11.00000   3.0000   6.00000
# ...      ...   ...    ...  ...   ...        ...       ...      ...       ...
# 34879  34880  2017      2   21     7  69.626367  91.48269   2.0000  32.49725
# 34880  34881  2017      2   21     8  69.626367  91.48269   2.0000  32.49725
# 34883  34884  2017      2   21    11  69.626367  91.48269   2.0000  32.49725
# 34885  34886  2017      2   21    13  69.626367  91.48269   2.0000  32.49725
# 34935  34936  2017      2   23    15   4.000000   4.00000   2.0000   8.00000
#
# ...

# %%
Huairou_df.O3.value_counts()
# Out:
# O3
# 2.0000      3300
# 4.0000       322
# 16.0000      315
# 12.0000      313
# 3.0000       307
#             ...
# 47.5524        1
# 129.3768       1
# 169.8606       1
# 318.0000       1
# 356.0000       1
# Name: count, Length: 812, dtype: int64

# %%
Huairou_df.O3.fillna(value=2.0000, inplace=True)

# %%
Huairou_df[(Huairou_df['TEMP'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5       PM10   SO2   NO2      CO  \
# 15899  15900  2014     12   23    11   53.0   78.00000  27.0  48.0  1100.0
# 15900  15901  2014     12   23    12   47.0   74.00000  26.0  41.0   900.0
# 16740  16741  2015      1   27    12   14.0   14.00000  18.0  18.0   400.0
# 16741  16742  2015      1   27    13   13.0   13.00000   2.0   9.0   300.0
# 16752  16753  2015      1   28     0   48.0   48.00000   6.0  32.0  1300.0
# 16761  16762  2015      1   28     9   12.0   20.00000   2.0  28.0   500.0
# 16764  16765  2015      1   28    12   10.0   13.00000   3.0   9.0   300.0
# 16765  16766  2015      1   28    13   10.0   12.00000  19.0  17.0   300.0
# 16766  16767  2015      1   28    14   12.0   13.00000  14.0  16.0   300.0
# 16810  16811  2015      1   30    10   22.0   22.00000   9.0  28.0   600.0
# 16811  16812  2015      1   30    11   16.0   16.00000   3.0  12.0   400.0
# ...

# %%
Huairou_df = Huairou_df.dropna(axis=0, subset=['TEMP'])

# %%
print("Jumlah missing values: \n", Huairou_df.isna().sum())
# Out:
# Jumlah missing values:
#  No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         2
# DEWP         2
# RAIN         4
# wd         257
# WSPM         4
# station      0
# dtype: int64

# %%
Huairou_df[(Huairou_df['wd'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5       PM10   SO2    NO2  \
# 14986  14987  2014     11   15    10   42.000000   82.00000  27.0   51.0
# 15118  15119  2014     11   20    22  308.000000  362.00000   9.0  132.0
# 15493  15494  2014     12    6    13    8.000000    8.00000   8.0   10.0
# 16745  16746  2015      1   27    17   69.626367   91.48269  15.0   18.0
# 17183  17184  2015      2   14    23  234.000000  238.00000  36.0   48.0
# ...      ...   ...    ...  ...   ...         ...        ...   ...    ...
# 34701  34702  2017      2   13    21  111.000000  182.00000  19.0   92.0
# 34725  34726  2017      2   14    21  238.000000  246.00000  23.0   77.0
# 34795  34796  2017      2   17    19   21.000000   52.00000   6.0   47.0
# 34875  34876  2017      2   21     3   23.000000   36.00000   6.0   21.0
# 35024  35025  2017      2   27     8   42.000000   64.00000   4.0   53.0
#
#            CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# ...

# %%
Huairou_df.wd.value_counts()
# Out:
# wd
# NW     4941
# WNW    4876
# NE     2251
# E      2159
# W      2138
# SE     2112
# ENE    2026
# ESE    2022
# SW     1795
# NNE    1687
# NNW    1663
# SSE    1573
# WSW    1468
# N      1367
# SSW    1350
# S      1328
# Name: count, dtype: int64

# %%
Huairou_df.wd.fillna(value="NW", inplace=True)

# %%
Huairou_df[(Huairou_df['wd'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
Aotizhongxin_df['PM2.5'].fillna(value=Aotizhongxin_df['PM2.5'].mean(), inplace=True)
Aotizhongxin_df.NO2.value_counts()
Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
Aotizhongxin_df.SO2.fillna(value=2.0000, inplace=True)
print("Jumlah missing values: \n", Aotizhongxin_df.isna().sum())
Aotizhongxin_df[(Aotizhongxin_df['TEMP'].isna())]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
#       2 Aotizhongxin_df['PM2.5'].fillna(value=Aotizhongxin_df['PM2.5'].mean(), inplace=True)
#       3 Aotizhongxin_df.NO2.value_counts()
#
# NameError: name 'Aotizhongxin_df' is not defined
