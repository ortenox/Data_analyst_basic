# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Shunyi_df = pd.read_csv("https://raw.githubusercontent.com/ortenox/data_analyst_project/main/PRSA_Data_Shunyi_20130301-20170228.csv")

# %%
Shunyi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %%
Shunyi_df.info()
print("Jumlah missing values: \n", Shunyi_df.isna().sum())
print("Jumlah duplikasi: ", Shunyi_df.duplicated().sum())
Shunyi_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# Jumlah missing values:
# ...

# %%
Shunyi_df[(Shunyi_df['PM2.5'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 204      205  2013      3    9    12    NaN   NaN  NaN   NaN    NaN  90.0
# 205      206  2013      3    9    13    NaN   NaN  NaN   NaN    NaN  90.0
# 206      207  2013      3    9    14    NaN   NaN  NaN   NaN    NaN  90.0
# 207      208  2013      3    9    15    NaN   NaN  NaN   NaN    NaN  90.0
# 208      209  2013      3    9    16    NaN   NaN  NaN   NaN    NaN  90.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 34880  34881  2017      2   21     8    NaN   NaN  NaN   NaN    NaN   NaN
# 34883  34884  2017      2   21    11    NaN   NaN  NaN   NaN    NaN   NaN
# 34885  34886  2017      2   21    13    NaN   NaN  NaN   NaN    NaN   NaN
# 34936  34937  2017      2   23    16    NaN   NaN  2.0  14.0  300.0  84.0
# 34937  34938  2017      2   23    17    NaN   NaN  2.0  17.0  300.0   NaN
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
Shunyi_df['PM2.5'].fillna(value=Shunyi_df['PM2.5'].mean(), inplace=True)

# %%
Shunyi_df[(Shunyi_df['PM2.5'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Shunyi_df[(Shunyi_df['PM10'].isna())]
# Out:
#           No  year  month  day  hour      PM2.5  PM10   SO2   NO2     CO  \
# 31        32  2013      3    2     7  13.000000   NaN  12.0  31.0  700.0
# 88        89  2013      3    4    16  13.000000   NaN   8.0  21.0  500.0
# 204      205  2013      3    9    12  79.491602   NaN   NaN   NaN    NaN
# 205      206  2013      3    9    13  79.491602   NaN   NaN   NaN    NaN
# 206      207  2013      3    9    14  79.491602   NaN   NaN   NaN    NaN
# ...      ...   ...    ...  ...   ...        ...   ...   ...   ...    ...
# 34880  34881  2017      2   21     8  79.491602   NaN   NaN   NaN    NaN
# 34883  34884  2017      2   21    11  79.491602   NaN   NaN   NaN    NaN
# 34885  34886  2017      2   21    13  79.491602   NaN   NaN   NaN    NaN
# 34936  34937  2017      2   23    16  79.491602   NaN   2.0  14.0  300.0
# 34937  34938  2017      2   23    17  79.491602   NaN   2.0  17.0  300.0
#
#          O3  TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
Shunyi_df['PM10'].fillna(value=Shunyi_df['PM10'].mean(), inplace=True)

# %%
Shunyi_df[(Shunyi_df['PM10'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Shunyi_df[(Shunyi_df['SO2'].isna())]
# Out:
#           No  year  month  day  hour      PM2.5        PM10  SO2  NO2     CO  \
# 2          3  2013      3    1     2  14.000000   14.000000  NaN  7.0  200.0
# 98        99  2013      3    5     2  93.000000  106.000000  NaN  5.0  200.0
# 194      195  2013      3    9     2  64.000000   93.000000  NaN  5.0  200.0
# 204      205  2013      3    9    12  79.491602   98.737026  NaN  NaN    NaN
# 205      206  2013      3    9    13  79.491602   98.737026  NaN  NaN    NaN
# ...      ...   ...    ...  ...   ...        ...         ...  ...  ...    ...
# 34879  34880  2017      2   21     7  79.491602   98.737026  NaN  NaN    NaN
# 34880  34881  2017      2   21     8  79.491602   98.737026  NaN  NaN    NaN
# 34883  34884  2017      2   21    11  79.491602   98.737026  NaN  NaN    NaN
# 34885  34886  2017      2   21    13  79.491602   98.737026  NaN  NaN    NaN
# 34938  34939  2017      2   23    18   9.000000   21.000000  NaN  NaN    NaN
#
# ...

# %%
Shunyi_df.SO2.value_counts()
# Out:
# SO2
# 2.0000      10335
# 3.0000       3202
# 4.0000       1689
# 5.0000       1272
# 6.0000       1122
#             ...
# 128.0000        1
# 9.9960          1
# 140.0000        1
# 12.2808         1
# 239.0000        1
# Name: count, Length: 267, dtype: int64

# %%
Shunyi_df.SO2.fillna(value=2.0000, inplace=True)

# %%
Shunyi_df[(Shunyi_df['SO2'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
print("Jumlah missing values: \n", Shunyi_df.isna().sum())
# Out:
# Jumlah missing values:
#  No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5         0
# PM10          0
# SO2           0
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64

# %%
Shunyi_df[(Shunyi_df['NO2'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10  SO2  NO2     CO  \
# 4          5  2013      3    1     4   12.000000   12.000000  3.0  NaN  200.0
# 100      101  2013      3    5     4  110.000000  133.000000  5.0  NaN  200.0
# 196      197  2013      3    9     4  119.000000  131.000000  7.0  NaN  100.0
# 204      205  2013      3    9    12   79.491602   98.737026  2.0  NaN    NaN
# 205      206  2013      3    9    13   79.491602   98.737026  2.0  NaN    NaN
# ...      ...   ...    ...  ...   ...         ...         ...  ...  ...    ...
# 34879  34880  2017      2   21     7   79.491602   98.737026  2.0  NaN    NaN
# 34880  34881  2017      2   21     8   79.491602   98.737026  2.0  NaN    NaN
# 34883  34884  2017      2   21    11   79.491602   98.737026  2.0  NaN    NaN
# 34885  34886  2017      2   21    13   79.491602   98.737026  2.0  NaN    NaN
# 34938  34939  2017      2   23    18    9.000000   21.000000  2.0  NaN    NaN
#
# ...

# %%
Shunyi_df.NO2.value_counts()
# Out:
# NO2
# 10.0000     640
# 13.0000     579
# 11.0000     573
# 12.0000     571
# 9.0000      557
#            ...
# 55.4310       1
# 69.1861       1
# 8.8279        1
# 62.4112       1
# 184.0000      1
# Name: count, Length: 517, dtype: int64

# %%
Shunyi_df.NO2.describe()
# Out:
# count    33699.000000
# mean        43.908865
# std         30.996828
# min          2.000000
# 25%         19.000000
# 50%         37.000000
# 75%         62.000000
# max        258.000000
# Name: NO2, dtype: float64

# %%
Shunyi_df['NO2'].fillna(value=Shunyi_df['NO2'].mean(), inplace=True)

# %%
Shunyi_df[(Shunyi_df['NO2'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Shunyi_df[(Shunyi_df['CO'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10      SO2  \
# 3          4  2013      3    1     3   12.000000   12.000000   3.0000
# 99       100  2013      3    5     3   98.000000  116.000000   5.0000
# 120      121  2013      3    6     0  200.000000  208.000000  79.6824
# 131      132  2013      3    6    11  164.000000  174.000000  87.1080
# 178      179  2013      3    8    10  174.000000  196.000000  74.2560
# ...      ...   ...    ...  ...   ...         ...         ...      ...
# 34879  34880  2017      2   21     7   79.491602   98.737026   2.0000
# 34880  34881  2017      2   21     8   79.491602   98.737026   2.0000
# 34883  34884  2017      2   21    11   79.491602   98.737026   2.0000
# 34885  34886  2017      2   21    13   79.491602   98.737026   2.0000
# 34938  34939  2017      2   23    18    9.000000   21.000000   2.0000
#
#              NO2  CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
Shunyi_df['CO'].fillna(value=Shunyi_df['CO'].mean(), inplace=True)

# %%
Shunyi_df[(Shunyi_df['CO'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Shunyi_df[(Shunyi_df['O3'].isna())]
# Out:
#           No  year  month  day  hour      PM2.5        PM10      SO2  \
# 3          4  2013      3    1     3  12.000000   12.000000   3.0000
# 483      484  2013      3   21     3  88.000000   76.000000   3.0000
# 484      485  2013      3   21     4  74.000000   92.000000   3.0000
# 578      579  2013      3   25     2  79.000000  142.000000  10.0000
# 579      580  2013      3   25     3  67.000000  119.000000   3.7128
# ...      ...   ...    ...  ...   ...        ...         ...      ...
# 34879  34880  2017      2   21     7  79.491602   98.737026   2.0000
# 34880  34881  2017      2   21     8  79.491602   98.737026   2.0000
# 34883  34884  2017      2   21    11  79.491602   98.737026   2.0000
# 34885  34886  2017      2   21    13  79.491602   98.737026   2.0000
# 34937  34938  2017      2   23    17  79.491602   98.737026   2.0000
#
#              NO2           CO  O3  TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
Shunyi_df.O3.value_counts()
# Out:
# O3
# 2.0000      3478
# 4.0000       774
# 3.0000       714
# 5.0000       611
# 6.0000       550
#             ...
# 13.4946        1
# 50.1228        1
# 16.9218        1
# 80.9676        1
# 311.0000       1
# Name: count, Length: 961, dtype: int64

# %%
Shunyi_df.O3.fillna(value=2.0000, inplace=True)

# %%
Shunyi_df[(Shunyi_df['TEMP'].isna())]
# Out:
#           No  year  month  day  hour  PM2.5        PM10   SO2         NO2  \
# 16760  16761  2015      1   28     8    7.0    7.000000   2.0   15.000000
# 16790  16791  2015      1   29    14   32.0   32.000000   4.0   31.000000
# 16812  16813  2015      1   30    12   15.0   15.000000   2.0   17.000000
# 16813  16814  2015      1   30    13   12.0   12.000000   2.0   11.000000
# 16873  16874  2015      2    2     1  271.0  271.000000  73.0   82.000000
# 16907  16908  2015      2    3    11  225.0  225.000000  53.0   90.000000
# 16930  16931  2015      2    4    10   22.0   28.000000   6.0   40.000000
# 16932  16933  2015      2    4    12   16.0   16.000000   2.0   20.000000
# 16934  16935  2015      2    4    14   19.0   19.000000   2.0   18.000000
# 16982  16983  2015      2    6    14   27.0   27.000000  18.0   29.000000
# 17007  17008  2015      2    7    15    8.0    8.000000   2.0    8.000000
# 17053  17054  2015      2    9    13   87.0   87.000000  33.0   48.000000
# ...

# %%
Shunyi_df = Shunyi_df.dropna(axis=0, subset=['TEMP'])

# %%
print("Jumlah missing values: \n", Shunyi_df.isna().sum())
# Out:
# Jumlah missing values:
#  No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         0
# DEWP         3
# RAIN         0
# wd         438
# WSPM         0
# station      0
# dtype: int64

# %%
Shunyi_df[(Shunyi_df['wd'].isna())]
# Out:
#           No  year  month  day  hour       PM2.5        PM10   SO2  \
# 6764    6765  2013     12    7    20  380.000000  378.000000  44.0
# 16416  16417  2015      1   14     0  215.000000  215.000000  36.0
# 17182  17183  2015      2   14    22  389.000000  389.000000  62.0
# 17186  17187  2015      2   15     2  316.000000  316.000000  64.0
# 17192  17193  2015      2   15     8  291.000000  291.000000  62.0
# ...      ...   ...    ...  ...   ...         ...         ...   ...
# 34872  34873  2017      2   21     0   79.491602   98.737026   2.0
# 34903  34904  2017      2   22     7   82.000000   82.000000   4.0
# 34944  34945  2017      2   24     0   74.000000   80.000000  30.0
# 34946  34947  2017      2   24     2   71.000000   86.000000  24.0
# 35014  35015  2017      2   26    22   87.000000  118.000000  20.0
#
#               NO2           CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM  \
# 6764   121.000000  8500.000000   4.0  -0.1  1016.7  -2.2   0.0  NaN   0.1
# ...

# %%
Shunyi_df.wd.value_counts()
# Out:
# wd
# NNE    4540
# N      3877
# NE     3349
# SSE    2963
# SE     2665
# S      2613
# NW     2444
# WNW    2051
# NNW    1656
# SSW    1586
# ENE    1416
# ESE    1377
# W      1177
# E      1153
# SW      971
# WSW     737
# Name: count, dtype: int64

# %%
Shunyi_df.wd.fillna(value="ENE", inplace=True)

# %%
Shunyi_df[(Shunyi_df['wd'].isna())]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %%
Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
Aotizhongxin_df['PM2.5'].fillna(value=Aotizhongxin_df['PM2.5'].mean(), inplace=True)
Aotizhongxin_df.NO2.value_counts()
Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
Aotizhongxin_df.SO2.fillna(value=2.0000, inplace=True)
print("Jumlah missing values: \n", Aotizhongxin_df.isna().sum())
Aotizhongxin_df[(Aotizhongxin_df['TEMP'].isna())]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 Aotizhongxin_df[(Aotizhongxin_df['PM2.5'].isna())]
#       2 Aotizhongxin_df['PM2.5'].fillna(value=Aotizhongxin_df['PM2.5'].mean(), inplace=True)
#       3 Aotizhongxin_df.NO2.value_counts()
#
# NameError: name 'Aotizhongxin_df' is not defined
